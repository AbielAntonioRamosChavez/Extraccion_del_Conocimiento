# %% [markdown]
# # Datos Sinteticos
# ## Utilizacion de la libreria FAKER
# *Autor: Abiel Antonio Ramos Chavez*

# %%
import pandas as pd
import numpy as np 
import random

# %%
# Importamos la libreria Faker 
from faker import Faker

# %%
pip install Faker
# Out:
# Requirement already satisfied: Faker in c:\users\abiel\anaconda3\lib\site-packages (40.21.0)
# Requirement already satisfied: tzdata in c:\users\abiel\anaconda3\lib\site-packages (from Faker) (2025.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Creamos una instancia De Faker 
fake = Faker("es_MX")

# %%
# Generamos datos sinteticos o datos falsos 
datos = []
for i in range (100):
    datos.append(
        {
            "id_usuario": i +1,
            "nombre" : fake.name(),
            "correo" : fake.email(),
            "edad" : random.randint(18,65),
            "seguidores" : random.randint(50,5000),
            "plataforma" : random.choice(["Tiktok", "Instagram", "Youtube",])
        }
    )

# %%
dfInfluencer = pd.DataFrame(datos)

# %%
dfInfluencer
# Out:
#     id_usuario                         nombre                          correo  \
# 0            1            Sra. Cristal Toledo      madridzeferino@example.org
# 1            2    Pilar Itzel Valdivia Corona        angelfuentes@example.com
# 2            3              Lic. Raquel Ponce            aarteaga@example.org
# 3            4                   Diana Bernal    anguianoveronica@example.org
# 4            5             Lic. Luz Benavides              juan71@example.net
# ..         ...                            ...                             ...
# 95          96  Adela Catalina Llamas Fuentes       ameliadel-rio@example.net
# 96          97             Luis Alfredo Mateo             caguayo@example.org
# 97          98            Lucas Brito Holguín  marco-antonioamaya@example.org
# 98          99     Angélica Guillermina Pérez            arturo01@example.com
# 99         100            Adela Colunga Nieto     araceligonzalez@example.org
#
#     edad  seguidores plataforma
# 0     59        3990     Tiktok
# 1     60         539    Youtube
# 2     58        3189  Instagram
# 3     31        4131  Instagram
# 4     58        2641  Instagram
# ..   ...         ...        ...
# 95    37        1268     Tiktok
# 96    24        3564     Tiktok
# 97    58        3197    Youtube
# 98    18        4346    Youtube
# 99    65        4914     Tiktok
#
# [100 rows x 6 columns]

# %%
dfInfluencer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_usuario  100 non-null    int64
#  1   nombre      100 non-null    object
#  2   correo      100 non-null    object
#  3   edad        100 non-null    int64
#  4   seguidores  100 non-null    int64
#  5   plataforma  100 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 4.8+ KB

# %%
dfInfluencer.describe()
# Out:
#        id_usuario        edad   seguidores
# count  100.000000  100.000000   100.000000
# mean    50.500000   42.350000  2620.520000
# std     29.011492   15.187964  1405.120847
# min      1.000000   18.000000   174.000000
# 25%     25.750000   28.000000  1354.500000
# 50%     50.500000   43.500000  2771.500000
# 75%     75.250000   56.250000  3706.250000
# max    100.000000   65.000000  4967.000000

# %%
dfInfluencer.describe(include="all")
# Out:
#         id_usuario               nombre                      correo  \
# count   100.000000                  100                         100
# unique         NaN                  100                         100
# top            NaN  Sra. Cristal Toledo  madridzeferino@example.org
# freq           NaN                    1                           1
# mean     50.500000                  NaN                         NaN
# std      29.011492                  NaN                         NaN
# min       1.000000                  NaN                         NaN
# 25%      25.750000                  NaN                         NaN
# 50%      50.500000                  NaN                         NaN
# 75%      75.250000                  NaN                         NaN
# max     100.000000                  NaN                         NaN
#
#               edad   seguidores plataforma
# count   100.000000   100.000000        100
# unique         NaN          NaN          3
# top            NaN          NaN  Instagram
# freq           NaN          NaN         39
# mean     42.350000  2620.520000        NaN
# std      15.187964  1405.120847        NaN
# min      18.000000   174.000000        NaN
# 25%      28.000000  1354.500000        NaN
# 50%      43.500000  2771.500000        NaN
# 75%      56.250000  3706.250000        NaN
# max      65.000000  4967.000000        NaN

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (8,4))
sns.histplot(dfInfluencer["edad"], bins=10)
plt.title("Distribucion de edades")
plt.show()

# %%
#Graficamos la cantidad de usuarios por plataforma
plt.figure(figsize = (8,4))
sns.countplot(x="plataforma", data= dfInfluencer)
plt.title("Cantidad de usuarios por plataforma")
plt.show()
